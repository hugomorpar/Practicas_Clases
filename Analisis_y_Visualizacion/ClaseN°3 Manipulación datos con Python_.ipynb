# %% [markdown]
# # Manipulación de datos con Python
# ![images.jpg](attachment:images.jpg)
#
#
# Docente: James Tomalá Robles

# %% [markdown]
# ## Tipos de secuencia de datos
#
# ![imagen.png](attachment:imagen.png)

# %%
## Generar una lista 
X= [1, 2 , 4]

#generar una tupla 

#generar un conjunto ( set )

#generar un diccionario
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>

# %%
#generar un array o vector 

#generar un dataframe
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %%
## Defina un data frame con index
# Out:
#          nombre  edad
# alumno 1   Juan    22
# alumno 2  Maria    52

# %% [markdown]
# ## Abandono Clientes de Telefonía
#
# ![Sin%20t%C3%ADtulo.jpg](attachment:Sin%20t%C3%ADtulo.jpg)

# %% [markdown]
# ## Lectura archivos CSV

# %%
import pandas as pd 

df = pd.read_csv("C:/data/telecom_churn.csv")

# %% [markdown]
# ## Explorando la tabla

# %%
# primeros registros
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
## últimos registros
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
## Dimensión de tabla
# Out:
# (3333, 20)

# %%
## Columnas de la tabla
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# tipo de datos de las columnas 
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
# información de la tabla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# ## Selección de filas y columnas con loc e iloc
#
# ### iloc utiliza los "índices" para la selección
#
#
# ### loc utiliza los "etiquetas (labels)"   para la selección

# %%
## Selección de filas con index  

df2 = df.iloc[__________ , :]

display(df2.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 5    AL             118        510                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 5                      0              223.4               98
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# ...

# %%
## Selección de columnas con el index 
# seleccionar las columnas con index 2 y 3 

df2  = df.iloc[ ___ , _____]

display(df2.head())
# Out:
#    Area code International plan Voice mail plan
# 2        415                 No              No
# 3        408                Yes              No

# %%
# Seleccionar con iloc las columnas "Area code" , "International plan", "Voice mail plan"

# %%
# Seleccionar con loc las columnas "Area code" , "International plan", "Voice mail plan"

# %% [markdown]
# Preguntas Feedback - fin primera cápsula

# %% [markdown]
# ## Cápsula 2
#
# ### Haciendo filtros en pandas
#
# ![pandas-filter.avif](attachment:pandas-filter.avif)

# %%
df.shape
# Out:
# (3333, 20)

# %%
# ¿Cuántos clientes tienen Total night minutes mayor a 100 ?
# Out:
# (3259, 20)

# %%
# Filtrar los que corresponden al estado de OH o NY (usar isin)
# Out:
# (161, 20)

# %%
## Seleccione todos los registros que abandonaron la telefónica

# %%
# Filtrar los clientes que abandonaron el servicio y tiene  un 'Total day charge' menor a 100
# Out:
# (483, 20)

# %% [markdown]
# ## Estadísticos descriptivos y agregaciones básicas

# %%
# Calcular estadísticas descriptivas para todas las variables cuantitativas
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
## Calcular estadísticas descriptivas sólo para 'Total day minutes'
# Out:
# count    3333.000000
# mean      179.775098
# std        54.467389
# min         0.000000
# 25%       143.700000
# 50%       179.400000
# 75%       216.400000
# max       350.800000
# Name: Total day minutes, dtype: float64

# %% [markdown]
# ## Cálculo de valor estandarizado
# ![F%C3%B3rmula+de+la+Estandarizaci%C3%B3n.jpg](attachment:F%C3%B3rmula+de+la+Estandarizaci%C3%B3n.jpg)

# %%
## estandarizar la columna 'Total day minutes'
# Out:
# 0    1.567
# 1   -0.334
# 2    1.168
# 3    2.197
# 4   -0.240
# Name: estandar, dtype: float64

# %% [markdown]
# ## Outlier según criterio de desviación estándar
#
# Se debe establecer un umbral
#
# ![imagen.png](attachment:imagen.png)

# %%
## Identificar los Outliers usando el criterio de desviación estándar con umbral de 3
# Out:
# (9, 21)

# %% [markdown]
# ## Cálculo de percentiles

# %%
percentiles= np.percentile(df['Total day minutes'], [_______________])

# %%
# determinar outlier de 'Total day minutes' aquellos que sean mayor al percentil 99 

p1 = np.percentile(df['Total day minutes'], ___)
p99 = np.percentile(df['Total day minutes'], ___)

# %% [markdown]
# ## Identificación de Outlier con percentiles

# %%
# determinar outlier de 'Total day minutes' aquellos que sean mayor al percentil 99

# %% [markdown]
# fin segunda cálcula, preguntas de retroalimentación
