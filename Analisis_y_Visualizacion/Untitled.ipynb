# %%
import pandas as pd

# %%
df=pd.read_excel('Codigo.xlsx')

# %%
display(df)
# Out:
#     Unnamed: 0         import  \
# 0          NaN       read_csv
# 1          NaN         head()
# 2          NaN         tail()
# 3          NaN          shape
# 4          NaN         dtypes
# 5          NaN           drop
# 6          NaN           melt
# 7          NaN          pivot
# 8          NaN    sort_values
# 9          NaN        decribe
# 10         NaN         append
# 11         NaN          merge
# 12         NaN        groupby
# 13         NaN         concat
# 14         NaN         np.max
# 15         NaN     isnull.sum
# 16         NaN        display
# 17         NaN         info()
# 18         NaN            loc
# 19         NaN           iloc
# 20         NaN        columns
# 21         NaN         assign
# 22         NaN           isin
# 23         NaN  nueva columna
# 24         NaN     skipfooter
# 25         NaN              >
# 26         NaN           True
# 27         NaN          print
#
#    Importar libreria (pandas. numpy, matplotlib, seaborn)  \
# ...
